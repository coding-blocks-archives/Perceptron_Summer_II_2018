# %% [markdown]
# # Clustering

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_blobs

# %%
# Generate data
X, y = make_blobs(n_samples=500, centers=5)
print X.shape, y.shape
# Out:
# (500, 2) (500,)

# %%
plt.figure(0)
plt.grid("on")
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
print X.shape
# Out:
# (500, 2)

# %%
# Create initial clusters
k = 5

colors = ['green', 'blue', 'red', 'yellow', 'orange', 'pink']

clusters = {}

for kx in range(k):
    center = 10.0*(2*np.random.random((X.shape[1],)) - 1)
    points = []
    cluster = {
        'center': center,
        'points': points,
        'color': colors[kx]
    }
    clusters[kx] = cluster

print clusters
# Out:
# {0: {'color': 'green', 'points': [], 'center': array([9.775282  , 5.98844157])}, 1: {'color': 'blue', 'points': [], 'center': array([-3.58684471, -1.32859276])}, 2: {'color': 'red', 'points': [], 'center': array([-7.66922173, -9.70141616])}, 3: {'color': 'yellow', 'points': [], 'center': array([-7.78488331,  0.18744666])}, 4: {'color': 'orange', 'points': [], 'center': array([ 3.71617393, -8.65310364])}}

# %%
# print clusters

# %%
def distance(x1, x2):
    return np.sqrt(np.sum((x1-x2)**2))

# %%
# For each point in dataset
for ix in range(X.shape[0]):
    dist = []
    curr_x = X[ix]
    
    for kx in range(k):
        d = distance(curr_x, clusters[kx]['center'])
        dist.append(d)
    # Get the respective cluster for this point
    current_cluster_id = np.argmin(dist)
    
    clusters[current_cluster_id]['points'].append(curr_x)
    
for kx in range(k):
    pts = np.array(clusters[kx]['points'])
    # print pts.shape
    clusters[kx]['coords'] = pts

plt.figure(0)
plt.grid("on")
for kx in range(k):
    pts = clusters[kx]['coords']
    try:
        plt.scatter(pts[:, 0], pts[:, 1], color=clusters[kx]['color'])
    except:
        pass
    
    center = clusters[kx]['center']
    plt.scatter(center[0], center[1], color='black', s=100, marker='*')


for kx in range(k):
    if clusters[kx]['coords'].shape[0] > 0:
        new_center = clusters[kx]['coords'].mean(axis=0)
    else:
        new_center = clusters[kx]['center']
    clusters[kx]['center'] = new_center
    clusters[kx]['points'] = []
    

plt.figure(1)
plt.grid("on")
for kx in range(k):
    pts = clusters[kx]['coords']
    try:
        plt.scatter(pts[:, 0], pts[:, 1], color=clusters[kx]['color'])
    except:
        pass
    
    center = clusters[kx]['center']
    plt.scatter(center[0], center[1], color='black', s=100, marker='*')
