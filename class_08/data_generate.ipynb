# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples=500, n_features=1, noise=5.91)
print X.min(), X.max(), y.min(), y.max()
# Out:
# -2.9392261067956835 2.8495343566712603 -148.3124099011946 141.7327814147901

# %%
plt.scatter(X[:, 0], y[:])

# %%
# Y = X**3 + X**2

# %%
# plt.scatter(X**3, Y)

# %%
def f(x):
    return 5*x**5 + 4*x**2 - 3.0 + 50*(2*np.random.random()-1)

# %%
k1 = np.asarray([f(x) for x in range(-100, 100)])
k2 = np.asarray([f(x) for x in range(-100, 100)])

# %%
plt.scatter(range(-100, 100), k1)
plt.scatter(range(-100, 100), k2)
